# %% [markdown]
# # Certaines musiques re-apparaissent dans le classement
#
# (ex : pour noel,la saint valentin ,la sortie d'un nouveau son ou bien la mort du chanteur)
#
# (parfois un son reste dans les dernieres places , sort du classment et revient dans les dernieres)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import dataset

# %%
songs_df=pd.read_csv('my_data/songs_billboard.csv')

# %%
artists_df=pd.read_csv('my_data/artistes_billboard.csv')

# %%
billboard = pd.read_csv('my_data/my_billboard.csv')

# %%
len(billboard)
# Out:
# 320500

# %%
## Calcul d'une variable : plus grand ecrat de temps entre deux apparition dans le classement

# %% [markdown]
# ### Afficher les musique a etudie

# %%
reaparitionSongs=songs_df[songs_df['comboInstance'] > 4].sort_values(by='comboInstance', ascending=False)

# %%
reaparitionSongs
# Out:
#                                                   SongID  year  comboWeek  \
# 8578         All I Want For Christmas Is YouMariah Carey  2000         35
# 5069         Rockin' Around The Christmas TreeBrenda Lee  1960         31
# 18116  The Christmas Song (Merry Christmas To You)Nat...  1960         19
# 7346                         Jingle Bell RockBobby Helms  1958         29
# 8555                                  Sex With MeRihanna  2016         15
# 26141                         White ChristmasBing Crosby  1958         16
# 25322                  You Know I'm No GoodAmy Winehouse  2007         13
# 23796                                 El AmanteNicky Jam  2017         15
# 16873                             GoosebumpsTravis Scott  2016         34
# 23239                                  HomeMichael Buble  2005         20
# 21976                            ThrillerMichael Jackson  1984         19
# 22863                            Ocean EyesBillie Eilish  2018         20
# ...

# %%
reaparitionSongs.iloc[2]['SongID']
# Out:
# 'The Christmas Song (Merry Christmas To You)Nat King Cole'

# %% [markdown]
# ### Exemple de 'All I Want For Christmas Is You' de Mariah Carey
#
# **La musique est sortis en 2000**, est rentree une semaine dans le top 100.
# Quelque annes plus tard en 2012 la musique rentre a nouveau dans le classement (au periode de noel)
# Toutes les années suivantes la musique va a nouveau etre dans le classement aux semaines proches de noel.
#
# **L'apparition en 2012** est surement du a l'apparition des platformes de streaming

# %%
songId='All I Want For Christmas Is YouMariah Carey'

xx=billboard[billboard['SongID']==songId]
xx=xx.sort_values(by='date', ascending=True)
xx
# Out:
#                                                      url      WeekID  \
# 27371  https://www.billboard.com/charts/hot-100/2000-...    1/8/2000
# 78519  https://www.billboard.com/charts/hot-100/2012-...  12/22/2012
# 78867  https://www.billboard.com/charts/hot-100/2012-...  12/29/2012
# 79261  https://www.billboard.com/charts/hot-100/2013-...    1/5/2013
# 20423  https://www.billboard.com/charts/hot-100/2013-...  12/21/2013
# 20482  https://www.billboard.com/charts/hot-100/2013-...  12/28/2013
# 20534  https://www.billboard.com/charts/hot-100/2014-...    1/4/2014
# 21329  https://www.billboard.com/charts/hot-100/2014-...  12/20/2014
# 21341  https://www.billboard.com/charts/hot-100/2014-...  12/27/2014
# 21351  https://www.billboard.com/charts/hot-100/2015-...    1/3/2015
# 21456  https://www.billboard.com/charts/hot-100/2015-...  12/19/2015
# 21461  https://www.billboard.com/charts/hot-100/2015-...  12/26/2015
# 21466  https://www.billboard.com/charts/hot-100/2016-...    1/2/2016
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import (YEARLY,MONTHLY, DateFormatter,
                              rrulewrapper, RRuleLocator, drange)
import numpy as np
import datetime

# tick every 5th easter
rule = rrulewrapper(MONTHLY, interval=2)
loc = RRuleLocator(rule)
formatter = DateFormatter('%m/%y')

xxx=xx[xx['year'] > 2001]
dates = xxx['date'] #drange(date1, date2, delta)
s = xxx['Week Position']  # make up some random y values


fig, ax = plt.subplots(figsize=(10, 5))
plt.plot_date(dates, s)
ax.xaxis.set_major_locator(loc)
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_tick_params(rotation=45, labelsize=8)

plt.show()
# Out:
# M:\Programs\Miniconda3\envs\NLP\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
print("Nombre de fois present dans le classement :",len(xx))

print("\nEffectif par mois :")
print(xx['month'].value_counts())

print("\nEffectif par ans :")
print(xx['year'].value_counts().sort_index())

print("\nMoyenne position :")
print(xx['Week Position'].mean())
# Out:
# Nombre de fois present dans le classement : 35
#
# Effectif par mois :
# 12    23
# 1     10
# 11     2
# Name: month, dtype: int64
#
# Effectif par ans :
# 2000    1
# 2012    2
# 2013    3
# 2014    3
# 2015    3
# 2016    5
# 2017    5
# 2018    6
# 2019    7
# Name: year, dtype: int64
#
# Moyenne position :
# 21.8

# %% [markdown]
# ### Exemple de 'Sex With Me' de Rihanna
#
# Ma premiere hypothese en voyant le titre, etait que la musique revenait au moment de la saint valentin un peu comme Mariah Carey avec sa musique pour noel.
#
# Mais le titre n'a tout simplement pas perce, pendant des semaines il restait dans les dernieres places puis sortais du classement pour y revenir dans les dernieres places. Ceci explique pourquoi le titre est apparu a 6 moments discontinue dans le top100.

# %%
songId='Sex With MeRihanna'

xx=billboard[billboard['SongID']==songId]
xx=xx.sort_values(by='date', ascending=True)
xx
# Out:
#                                                      url      WeekID  \
# 56163  https://www.billboard.com/charts/hot-100/2016-...    8/6/2016
# 78860  https://www.billboard.com/charts/hot-100/2016-...    9/3/2016
# 20367  https://www.billboard.com/charts/hot-100/2016-...   9/24/2016
# 21303  https://www.billboard.com/charts/hot-100/2016-...   12/3/2016
# 21307  https://www.billboard.com/charts/hot-100/2016-...  12/10/2016
# 21316  https://www.billboard.com/charts/hot-100/2016-...  12/17/2016
# 21328  https://www.billboard.com/charts/hot-100/2016-...  12/24/2016
# 21340  https://www.billboard.com/charts/hot-100/2016-...  12/31/2016
# 21450  https://www.billboard.com/charts/hot-100/2017-...   1/14/2017
# 21453  https://www.billboard.com/charts/hot-100/2017-...   1/21/2017
# 21458  https://www.billboard.com/charts/hot-100/2017-...   1/28/2017
# 21464  https://www.billboard.com/charts/hot-100/2017-...    2/4/2017
# 21469  https://www.billboard.com/charts/hot-100/2017-...   2/11/2017
# ...

# %%
print("Nombre de fois present dans le classement :",len(xx))

print("\nEffectif par mois :")
print(xx['month'].value_counts())

print("\nEffectif par ans :")
print(xx['year'].value_counts().sort_index())

print("\nMoyenne position :")
print(xx['Week Position'].mean())
# Out:
# Nombre de fois present dans le classement : 15
#
# Effectif par mois :
# 12    5
# 2     3
# 1     3
# 9     2
# 8     1
# 3     1
# Name: month, dtype: int64
#
# Effectif par ans :
# 2016    8
# 2017    7
# Name: year, dtype: int64
#
# Moyenne position :
# 93.66666666666667

# %% [markdown]
# ### Exemple de 'Thriller' de Michael Jackson
#
# Depuis 2013 la musique apparait 1 fois dans le top 100 par ans, aux alentour de la deuxieme semaine du mois de novembre(sauf en 2016 et 2017).
#
# ----
#
# **mort MJ : 25 juin 2009** (ne coincide ni avec l'année ni avec la semaine)
#
# **sortis film 'this is it' : 28 octobre 2009** (ne coincide pas avec l'année, la semaine coincide mais semble etre un hasard car le film est sortis 4 ans avant que la musique ne reperce .
#
# //!\\ **sortis de la musique : 	2 novembre 1983** (50 ans avant la reapparition du titre, a une semaine pres ) //!\\
#
#     --> La meilleur explication de cette reaparition soudaine.
#
# **Pourquoi le titre ne revient pas pendant les années 2016 et 2017 ?**
#
#     Problament que le titre s'est fais oublier , mais qu'au 55eme anniversaire (2018) la musique reperce a nouveau dans le clasement . Ainsi que pour 2019, il ne reste plus qu'a voir si les gens l'auront oublié en 2020.

# %%
songId='ThrillerMichael Jackson'

xx=billboard[billboard['SongID']==songId]
xx=xx.sort_values(by='date', ascending=True)
xx
# Out:
#                                                      url      WeekID  \
# 71397  https://www.billboard.com/charts/hot-100/1984-...   2/11/1984
# 71398  https://www.billboard.com/charts/hot-100/1984-...   2/18/1984
# 71399  https://www.billboard.com/charts/hot-100/1984-...   2/25/1984
# 71400  https://www.billboard.com/charts/hot-100/1984-...    3/3/1984
# 71401  https://www.billboard.com/charts/hot-100/1984-...   3/10/1984
# 71402  https://www.billboard.com/charts/hot-100/1984-...   3/17/1984
# 71403  https://www.billboard.com/charts/hot-100/1984-...   3/24/1984
# 71404  https://www.billboard.com/charts/hot-100/1984-...   3/31/1984
# 71405  https://www.billboard.com/charts/hot-100/1984-...    4/7/1984
# 71406  https://www.billboard.com/charts/hot-100/1984-...   4/14/1984
# 71407  https://www.billboard.com/charts/hot-100/1984-...   4/21/1984
# 71408  https://www.billboard.com/charts/hot-100/1984-...   4/28/1984
# 71409  https://www.billboard.com/charts/hot-100/1984-...    5/5/1984
# ...

# %%
print("Nombre de fois present dans le classement :",len(xx))

print("\nEffectif par mois :")
print(xx['month'].value_counts())

print("\nEffectif par ans :")
print(xx['year'].value_counts().sort_index())

print("\nMoyenne position :")
print(xx['Week Position'].mean())
# Out:
# Nombre de fois present dans le classement : 19
#
# Effectif par mois :
# 11    5
# 3     5
# 4     4
# 2     3
# 5     2
# Name: month, dtype: int64
#
# Effectif par ans :
# 1984    14
# 2013     1
# 2014     1
# 2015     1
# 2018     1
# 2019     1
# Name: year, dtype: int64
#
# Moyenne position :
# 35.78947368421053

# %% [markdown]
# ### Exemple de 'Rockin' Around The Christmas Tree' de Brenda Lee
#
# Meme exemple que Mariah Carey, avec la seul difference que le titre revient a la mode en 2014 et non pas en 2012 comme pour 'All I want for chritmas is you'.

# %%
songId= 'Rockin\' Around The Christmas TreeBrenda Lee'

xx=billboard[billboard['SongID']==songId]
xx=xx.sort_values(by='date', ascending=True)
xx
# Out:
#                                                       url      WeekID  \
# 8457    https://www.billboard.com/charts/hot-100/1960-...  12/10/1960
# 104300  https://www.billboard.com/charts/hot-100/1960-...  12/17/1960
# 165790  https://www.billboard.com/charts/hot-100/1960-...  12/24/1960
# 227519  https://www.billboard.com/charts/hot-100/1960-...  12/31/1960
# 79882   https://www.billboard.com/charts/hot-100/1961-...   12/9/1961
# 80251   https://www.billboard.com/charts/hot-100/1961-...  12/16/1961
# 80451   https://www.billboard.com/charts/hot-100/1961-...  12/23/1961
# 80745   https://www.billboard.com/charts/hot-100/1961-...  12/30/1961
# 81058   https://www.billboard.com/charts/hot-100/1962-...    1/6/1962
# 20704   https://www.billboard.com/charts/hot-100/1962-...  12/15/1962
# 20734   https://www.billboard.com/charts/hot-100/1962-...  12/22/1962
# 20773   https://www.billboard.com/charts/hot-100/1962-...  12/29/1962
# ...

# %%
print("Nombre de fois present dans le classement :",len(xx))

print("\nEffectif par mois :")
print(xx['month'].value_counts())

print("\nEffectif par ans :")
print(xx['year'].value_counts().sort_index())

print("\nMoyenne position :")
print(xx['Week Position'].mean())
# Out:
# Nombre de fois present dans le classement : 31
#
# Effectif par mois :
# 12    24
# 1      7
# Name: month, dtype: int64
#
# Effectif par ans :
# 1960    4
# 1961    4
# 1962    4
# 2014    1
# 2015    1
# 2016    4
# 2017    3
# 2018    5
# 2019    5
# Name: year, dtype: int64
#
# Moyenne position :
# 37.61290322580645

# %% [markdown]
# ### Exemple de 'The Christmas Song (Merry Christmas To You)' de Nat King Cole
#
# Comme pour Mariah Carey , encore une musique de noel. Elle reaparait cette fois en debut janvier de l'année 2014 , pour reaparaitre 2 ans plus tard (2016) chaque année aux periodes des fetes.
#
# The Best Man Holiday : 15 Nov 2013

# %%
songId= 'The Christmas Song (Merry Christmas To You)Nat King Cole'

xx=billboard[billboard['SongID']==songId]
xx=xx.sort_values(by='date', ascending=True)
xx
# Out:
#                                                      url      WeekID  \
# 46206  https://www.billboard.com/charts/hot-100/1960-...  12/10/1960
# 46207  https://www.billboard.com/charts/hot-100/1960-...  12/17/1960
# 46208  https://www.billboard.com/charts/hot-100/1962-...  12/15/1962
# 46209  https://www.billboard.com/charts/hot-100/1962-...  12/22/1962
# 46210  https://www.billboard.com/charts/hot-100/1962-...  12/29/1962
# 46211  https://www.billboard.com/charts/hot-100/2014-...    1/4/2014
# 46212  https://www.billboard.com/charts/hot-100/2016-...    1/9/2016
# 46213  https://www.billboard.com/charts/hot-100/2017-...    1/7/2017
# 46214  https://www.billboard.com/charts/hot-100/2017-...  12/23/2017
# 46215  https://www.billboard.com/charts/hot-100/2017-...  12/30/2017
# 46216  https://www.billboard.com/charts/hot-100/2018-...    1/6/2018
# 46217  https://www.billboard.com/charts/hot-100/2018-...   12/8/2018
# 46218  https://www.billboard.com/charts/hot-100/2018-...  12/15/2018
# ...

# %%
print("Nombre de fois present dans le classement :",len(xx))

print("\nEffectif par mois :")
print(xx['month'].value_counts())

print("\nEffectif par ans :")
print(xx['year'].value_counts().sort_index())

print("\nMoyenne position :")
print(xx['Week Position'].mean())
# Out:
# Nombre de fois present dans le classement : 19
#
# Effectif par mois :
# 12    14
# 1      5
# Name: month, dtype: int64
#
# Effectif par ans :
# 1960    2
# 1962    3
# 2014    1
# 2016    1
# 2017    3
# 2018    5
# 2019    4
# Name: year, dtype: int64
#
# Moyenne position :
# 44.94736842105263

# %% [markdown]
# ### Exemple de 'You Know I'm No Good' de Amy Winehouse
#
# Sortis : 5 janvier 2007
#
# mort de Amy : 23 juillet 2011
#
# La musique n'a pas trés bien marché, les plusieurs reapparition ne sont pas dus a un evenement speciale (sauf peut etre pour la derniere apparition) .

# %%
songId= "You Know I'm No GoodAmy Winehouse"

xx=billboard[billboard['SongID']==songId]
xx=xx.sort_values(by='date', ascending=True)
xx
# Out:
#                                                       url     WeekID  \
# 139488  https://www.billboard.com/charts/hot-100/2007-...  3/31/2007
# 139489  https://www.billboard.com/charts/hot-100/2007-...  4/14/2007
# 139490  https://www.billboard.com/charts/hot-100/2007-...  4/21/2007
# 139491  https://www.billboard.com/charts/hot-100/2007-...   5/5/2007
# 139492  https://www.billboard.com/charts/hot-100/2007-...  5/12/2007
# 139493  https://www.billboard.com/charts/hot-100/2007-...  5/19/2007
# 139494  https://www.billboard.com/charts/hot-100/2007-...   6/2/2007
# 139495  https://www.billboard.com/charts/hot-100/2007-...  6/23/2007
# 139496  https://www.billboard.com/charts/hot-100/2007-...  6/30/2007
# 139497  https://www.billboard.com/charts/hot-100/2007-...   7/7/2007
# 139498  https://www.billboard.com/charts/hot-100/2007-...  7/14/2007
# 139499  https://www.billboard.com/charts/hot-100/2007-...  7/21/2007
# 139500  https://www.billboard.com/charts/hot-100/2008-...   3/1/2008
#
# ...

# %%
print("Nombre de fois present dans le classement :",len(xx))

print("\nEffectif par mois :")
print(xx['month'].value_counts())

print("\nEffectif par ans :")
print(xx['year'].value_counts().sort_index())

print("\nMoyenne position :")
print(xx['Week Position'].mean())
# Out:
# Nombre de fois present dans le classement : 13
#
# Effectif par mois :
# 7    3
# 6    3
# 5    3
# 4    2
# 3    2
# Name: month, dtype: int64
#
# Effectif par ans :
# 2007    12
# 2008     1
# Name: year, dtype: int64
#
# Moyenne position :
# 88.76923076923077
